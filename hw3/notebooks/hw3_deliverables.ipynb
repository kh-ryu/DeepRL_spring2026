# %% [markdown]
# # HW3 Deliverables
#
# This notebook loads the latest run for each required experiment prefix under `exp/` and writes all required figures to `figures/`.

# %%
from pathlib import Path
import sys

root = Path.cwd().resolve()
candidates = [
    root,
    root.parent,
    root / "hw3",
]

for candidate in candidates:
    if (candidate / "tools" / "plot_hw3_deliverables.py").exists():
        root = candidate
        break
else:
    raise FileNotFoundError("Could not find tools/plot_hw3_deliverables.py")

sys.path.insert(0, str(root))

from tools.plot_hw3_deliverables import generate_all_figures, notebook_summary

# %%
for line in notebook_summary():
    print(line)

generate_all_figures(root / "figures")
# Out:
# Section 2.4: CartPole eval return vs environment steps.
# Section 2.5: LunarLander and MsPacman train return and eval return on the same axes.
# Section 2.6: LunarLander learning-rate sweep with four settings.
# Section 3.4: HalfCheetah eval return vs environment steps.
# Section 3.5: HalfCheetah fixed vs auto-tuned return, plus auto-tuned temperature.
# Section 3.6: Hopper single-Q vs clipped double-Q for eval return and q values.
# {'2.4': PosixPath('/home/kanghyun/homework_spring2026/hw3/figures/sec_2_4_cartpole_eval_return.png'),
#  '2.5_lunarlander': PosixPath('/home/kanghyun/homework_spring2026/hw3/figures/sec_2_5_lunarlander_train_eval_return.png'),
#  '2.5_mspacman': PosixPath('/home/kanghyun/homework_spring2026/hw3/figures/sec_2_5_mspacman_train_eval_return.png'),
#  '2.6': PosixPath('/home/kanghyun/homework_spring2026/hw3/figures/sec_2_6_lunarlander_lr_sweep.png'),
#  '3.4': PosixPath('/home/kanghyun/homework_spring2026/hw3/figures/sec_3_4_halfcheetah_eval_return.png'),
#  '3.5': PosixPath('/home/kanghyun/homework_spring2026/hw3/figures/sec_3_5_halfcheetah_autotune.png'),
#  '3.6': PosixPath('/home/kanghyun/homework_spring2026/hw3/figures/sec_3_6_hopper_singleq_vs_clipq.png')}
